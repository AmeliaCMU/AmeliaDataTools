# %% [markdown]
# # Dataset graph plots

# %% [markdown]
# https://osmnx.readthedocs.io/en/stable/osmnx.html

# %%
# For reference: 
# G = ox.graph_from_bbox(north=lat_max, south=lat_min, east=lon_min, west=lon_max, custom_filter=graph_filter)
# G = ox.graph_from_xml(filename, simplify=True, retain_all=True, custom_filter=graph_filter)
# G = ox.graph_from_place(AIRPORT_NAME, simplify=True, retain_all=True, truncate_by_edge=True, buffer_dist=1000, custom_filter=graph_filter)

# %%
import contextily as ctx
import geopandas as gpd
import json 
import matplotlib.pyplot as plt
import numpy as np
import os
import osmnx as ox
import pandas as pd

from shapely.geometry import Point
from geopandas import GeoDataFrame
from shapely.geometry import  Point
from tqdm import tqdm
from itertools import groupby

# %%
AIRPORT = "kewr"
BASE_DIR = './swim'

TRAJECTORIES_DIR = os.path.join(BASE_DIR, 'raw_trajectories', AIRPORT)
MAP_DIR = os.path.join(BASE_DIR, 'maps', AIRPORT)
LIMITS_FILE = os.path.join(MAP_DIR, 'limits.json')

OUTPUT_DIR = f"./out/navgraph/{AIRPORT}"
os.makedirs(OUTPUT_DIR, exist_ok=True)
assert os.path.exists(BASE_DIR), f"Path {BASE_DIR} does not exist."
assert os.path.exists(LIMITS_FILE), f"Reference file {LIMITS_FILE} does not exist."

with open(LIMITS_FILE, 'r') as f:
    ref_data = json.load(f)

TRAJECTORY_FILES = [os.path.join(TRAJECTORIES_DIR, f) for f in os.listdir(TRAJECTORIES_DIR)]

AIRPORT_NAME = ref_data['airport_name']
CRS = ref_data['crs']
ESPG = int(CRS.split(':')[-1])

LAT_MIN, LAT_MAX = ref_data['limits']['lat']
LON_MIN, LON_MAX = ref_data['limits']['lon']
MAP_FILE = os.path.join(MAP_DIR, ref_data['map_shapefile'])

LIMITS_BBOX = (LAT_MIN, LAT_MAX, LON_MIN, LON_MAX)
print(f"Airport reference data:\n{json.dumps(ref_data, indent=4)}")
# Out:
# Airport reference data:
# {
#     "airport_name": "Newark Airport",
#     "airport_id": "kewr",
#     "ref_lat": 40.69017,
#     "ref_lon": -74.17266,
#     "range_scale": 1000.0,
#     "crs": "EPSG:4326",
#     "map_shapefile": "roads.shp",
#     "semantic_map": "semantic_map.png",
#     "north": 40.7078,
#     "south": 40.6728,
#     "west": -74.1897,
#     "east": -74.1545,
#     "limits": {
#         "lat": [
#             40.6728,
#             40.7078
#         ],
#         "lon": [
#             -74.1897,
#             -74.1545
#         ],
#         "x": [
#             -2.532900401486464,
#             2.8334783371265284
#         ],
#         "y": [
#             -3.393181410331392,
#             2.2264886373639223
#         ]
#     },
#     "ll_offset": 0.002
# }

# %%
data = pd.read_csv(TRAJECTORY_FILES[0])
data.head()
# Out:
#    Frame    ID  Altitude    Speed     Heading       Lat       Lon     Range  \
# 0      0  2954      12.5  22.0000  343.948975  40.70261 -74.15670  1.930806
# 1      0  3278      12.5   5.0000  179.497375  40.68393 -74.17292  0.693287
# 2      0    49      12.5   2.6875  147.191528  40.67482 -74.18339  1.930910
# 3      0  3812      12.5   0.0000   26.109009  40.68238 -74.17504  0.888150
# 4      0   278      12.5   6.3750  333.230867  40.70130 -74.15743  1.784553
#
#       Bearing         x         y
# 0   44.312887  1.381560  1.348815
# 1 -178.183245 -0.692939 -0.021979
# 2 -151.976966 -1.704528 -0.907193
# 3 -166.906652 -0.865060 -0.201200
# 4   46.159509  1.236076  1.287146

# %%
fig, ax = plt.subplots(1, 3, figsize = (20, 45))

# plot map 
gdf = gpd.read_file(MAP_FILE)
gd = gdf.to_crs(epsg=ESPG)
gd.plot(ax=ax[0])
gd.plot(ax=ax[1])
gd.plot(ax=ax[2])

ax[0].set_xlim(xmin=LON_MIN, xmax=LON_MAX)
ax[0].set_ylim(ymin=LAT_MIN, ymax=LAT_MAX)

plt.tight_layout()
ctx.add_basemap(ax[0], crs=gdf.crs,)
ctx.add_basemap(ax[1], crs=gdf.crs,)
ctx.add_basemap(ax[2], crs=gdf.crs,)

# create airports graph
graph_filter = '["aeroway"~"runway|taxiway|stopway"]'
airport_graph = ox.graph_from_place(
    AIRPORT_NAME, simplify=True, retain_all=True, truncate_by_edge=True, buffer_dist=1000, 
    custom_filter=graph_filter
)
ox.plot_graph(
    airport_graph, ax=ax[0], bgcolor="white", edge_color='black', edge_linewidth=1,
    node_size=30, node_color='blue', show=False, bbox=LIMITS_BBOX)
ax[0].invert_yaxis()
ax[0].invert_xaxis()

ox.plot_graph(
    airport_graph, ax=ax[1], bgcolor="white", edge_color='black', edge_linewidth=3,
    node_size=50, node_color='blue', show=False, bbox=LIMITS_BBOX)
ax[1].invert_yaxis()
ax[1].invert_xaxis()

# ox.plot_graph(
#     airport_graph, ax=ax[2], bgcolor="white", edge_color='black', edge_linewidth=3,
#     node_size=50, node_color='blue', show=False, bbox=LIMITS_BBOX)
# ax[2].invert_yaxis()
# ax[2].invert_xaxis()
ax[2].invert_yaxis()
ax[2].invert_xaxis()

unique_IDs = data.ID.unique()

offset = 0.003
num_trajs = 10
for n, ID in enumerate(unique_IDs):
    if n > num_trajs:
        break

    traj = data[:][data.ID == ID]    
    if n < num_trajs:
        continue
    # print(traj.shape)
    traj = traj[:30]
    geometry = [Point(xy) for xy in zip(traj.Lon, traj.Lat)]
    
    # plot raw trajectory 
    lon_min, lon_max = min(traj.Lon) - offset, max(traj.Lon) + offset
    lat_min, lat_max = min(traj.Lat) - offset, max(traj.Lat) + offset
    bbox = (lat_min, lat_max, lon_min, lon_max)

    ax[1].set_xlim(xmin=lon_min, xmax=lon_max)
    ax[1].set_ylim(ymin=lat_min, ymax=lat_max)

    ax[2].set_xlim(xmin=lon_min, xmax=lon_max)
    ax[2].set_ylim(ymin=lat_min, ymax=lat_max)

    # plot graph-based trajectory
    bbox_graph = ox.graph_from_bbox(
        north=lat_max, south=lat_min, east=lon_min, west=lon_max, simplify=True, retain_all=False, 
        custom_filter=graph_filter)
    
    bbox_graph = ox.consolidate_intersections(
        bbox_graph, tolerance=0.00040, rebuild_graph=True, dead_ends=True, reconnect_edges=True)

    ox.plot_graph(
        bbox_graph, ax=ax[2], bgcolor="white", edge_color='black', edge_linewidth=3,
        node_size=100, node_color='blue', show=False)

    nn, dist = ox.distance.nearest_nodes(bbox_graph, traj.Lon, traj.Lat, return_dist=True)
    dist = np.asarray(dist)
    idx = dist < 70
    dist = dist[idx].tolist()
    nn = np.asarray(nn)[idx].tolist()
    nn = [n[0] for n in groupby(nn)]

    on = nn[:-1]
    dn = nn[1:]

    routes = []
    for o, d in zip(on, dn):
        # Pairwise starts and ends
        path = ox.distance.shortest_path(bbox_graph, o, d)
        routes += path[:-1]
    routes += [path[-1]]

    gdf = GeoDataFrame(traj, geometry=geometry, crs=CRS, copy = False)
    gdf.plot(ax=ax[0], color='red', markersize=10)
    gdf.plot(ax=ax[1], color='red', markersize=30)
    
    ox.plot_graph_route(
        bbox_graph, routes, bgcolor="white", edge_color='black', edge_linewidth=2, node_size=100,
        node_color='blue', route_color='cyan', bbox=bbox, show=True, ax=ax[2]
    )
fig.savefig(f"{OUTPUT_DIR}/dummy.png", dpi=600, bbox_inches='tight')
# Out:
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid

# %%
def compute_route(G, trajectory, distance_threshold = 70):
    nn, dist = ox.distance.nearest_nodes(G, trajectory.Lon, trajectory.Lat, return_dist=True)
    dist = np.asarray(dist)
    idx = dist < distance_threshold
    dist = dist[idx].tolist()
    nn = np.asarray(nn)[idx].tolist()
    nn = [n[0] for n in groupby(nn)]
    
    if len(nn) <= 1:
        return []
    
    on = nn[:-1]
    dn = nn[1:]

    route = []
    path = None
    for o, d in zip(on, dn):
        # Pairwise starts and ends
        path = ox.distance.shortest_path(G, o, d)
        route += path[:-1]
    if not path is None:
        route += [path[-1]]
    
    return route

def compute_local_graph(lat_min, lat_max, lon_min, lon_max, osm_filter, tolerance = 0.0004, reduce=True):
    G = ox.graph_from_bbox(
        north=lat_max, south=lat_min, east=lon_min, west=lon_max, simplify=True, 
        retain_all=False, custom_filter=osm_filter)
    if reduce:
        G = ox.consolidate_intersections(
            G, tolerance=tolerance, rebuild_graph=True, dead_ends=True, reconnect_edges=True)
    return G

# %%
# %matplotlib agg

AIRPORT_FILTER = '["aeroway"~"runway|taxiway|stopway"]'
airport_graph = ox.graph_from_place(
    AIRPORT_NAME, simplify=True, retain_all=True, truncate_by_edge=True, buffer_dist=1000, 
    custom_filter=AIRPORT_FILTER
)

gdf = gpd.read_file(MAP_FILE)
gd = gdf.to_crs(epsg=ESPG)

# gdf = gpd.read_file(MAP_FILE)
# gd = gdf.to_crs(epsg=ESPG)
# gd.plot(ax=ax[0])
# gd.plot(ax=ax[1])
# gd.plot(ax=ax[2])

offset = 0.003
num_files = 100
num_trajectories = 1
trajectory_length = 30
tolerance = 0.0004
reduce = True

# fig, ax = plt.subplots(1, 2, figsize = (20, 30))
fig, ax = plt.subplots(figsize = (20, 30))

for i, trajectory_file in enumerate(tqdm(TRAJECTORY_FILES)):
    if i > num_files:
        break
    plt.tight_layout()
    
    data = pd.read_csv(trajectory_file)
    unique_IDs = data.ID.unique()

    for n, ID in enumerate(unique_IDs):
        if n > num_trajectories:
            break
        
        trajectory = data[:][data.ID == ID]    
        if n < num_trajectories:
            continue

        if trajectory.shape[0] < trajectory_length:
            continue
        trajectory = trajectory[:trajectory_length]

        # get limits of trajectory 
        lon_min, lon_max = min(trajectory.Lon) - offset, max(trajectory.Lon) + offset
        lat_min, lat_max = min(trajectory.Lat) - offset, max(trajectory.Lat) + offset
        bbox = (lat_min, lat_max, lon_min, lon_max)

        # get local graph 
        G_bbox = compute_local_graph(lat_min, lat_max, lon_min, lon_max, AIRPORT_FILTER, tolerance)
        
        # compute route on local graph 
        route = compute_route(G_bbox, trajectory)
        if len(route) <= 0:
            continue
        
        # get trajectory in a geopandas dataframe
        geometry = [Point(xy) for xy in zip(trajectory.Lon, trajectory.Lat)]

        # plot 
        gd.plot(ax=ax)
        ctx.add_basemap(ax, crs=gdf.crs)
        ax.set_xlim(xmin=lon_min, xmax=lon_max)
        ax.set_ylim(ymin=lat_min, ymax=lat_max)
        gdf = GeoDataFrame(trajectory, geometry=geometry, crs=CRS, copy = False)
        gdf.plot(ax=ax, color='red', markersize=30)
        ox.plot_graph(
            G_bbox, ax=ax, bgcolor="white", edge_color='black', edge_linewidth=3, node_size=100, 
            node_color='blue', show=False)
        ax.invert_yaxis(); ax.invert_xaxis()

        # # plot 
        # gd.plot(ax=ax[0])
        # ctx.add_basemap(ax[0], crs=gdf.crs)
        # ax[0].set_xlim(xmin=lon_min, xmax=lon_max)
        # ax[0].set_ylim(ymin=lat_min, ymax=lat_max)
        # gdf = GeoDataFrame(trajectory, geometry=geometry, crs=CRS, copy = False)
        # gdf.plot(ax=ax[0], color='red', markersize=30)
        # ox.plot_graph(
        #     G_bbox, ax=ax[0], bgcolor="white", edge_color='black', edge_linewidth=3, node_size=100, 
        #     node_color='blue', show=False)
        # ax[0].invert_yaxis(); ax[0].invert_xaxis()

        # gd.plot(ax=ax[1])
        # ctx.add_basemap(ax[1], crs=gdf.crs)  
        # ax[1].set_xlim(xmin=lon_min, xmax=lon_max)
        # ax[1].set_ylim(ymin=lat_min, ymax=lat_max)
        # ox.plot_graph(
        #     G_bbox, ax=ax[1], bgcolor="white", edge_color='black', edge_linewidth=3, node_size=100, 
        #     node_color='blue', show=True)
        # ox.plot_graph_route(
        #     G_bbox, route, bgcolor="white", edge_color='black', edge_linewidth=2, node_size=100,
        #     node_color='blue', route_color='cyan', bbox=bbox, show=True, ax=ax[1]
        # )
        # ax[1].invert_yaxis(); ax[1].invert_xaxis()
        fig.savefig(
            f"{OUTPUT_DIR}/file-{i}_trajectory-{n}_{int(reduce)}.png", dpi=100, bbox_inches='tight')
        plt.cla()
# Out:
#   0%|          | 0/1022 [00:00<?, ?it/s]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   0%|          | 2/1022 [00:01<14:53,  1.14it/s]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   0%|          | 3/1022 [00:03<20:30,  1.21s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   0%|          | 4/1022 [00:05<23:58,  1.41s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|          | 6/1022 [00:07<23:14,  1.37s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|          | 7/1022 [00:10<28:44,  1.70s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|          | 8/1022 [00:11<28:02,  1.66s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|          | 9/1022 [00:14<30:48,  1.82s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|          | 10/1022 [00:16<31:29,  1.87s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|          | 12/1022 [00:20<34:29,  2.05s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|▏         | 14/1022 [00:22<26:57,  1.61s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   1%|▏         | 15/1022 [00:24<27:05,  1.61s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 16/1022 [00:25<27:08,  1.62s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 17/1022 [00:27<27:48,  1.66s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 18/1022 [00:31<37:36,  2.25s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 19/1022 [00:33<35:08,  2.10s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 20/1022 [00:35<34:35,  2.07s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 21/1022 [00:37<33:23,  2.00s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 22/1022 [00:38<31:32,  1.89s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 23/1022 [00:40<30:58,  1.86s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 24/1022 [00:42<31:28,  1.89s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   2%|▏         | 25/1022 [00:46<42:08,  2.54s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 28/1022 [00:48<23:57,  1.45s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 29/1022 [00:53<38:46,  2.34s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 30/1022 [00:55<36:15,  2.19s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 31/1022 [00:57<36:16,  2.20s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 32/1022 [01:00<37:27,  2.27s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 33/1022 [01:02<35:37,  2.16s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 34/1022 [01:03<32:34,  1.98s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   3%|▎         | 35/1022 [01:05<30:52,  1.88s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▎         | 36/1022 [01:09<41:22,  2.52s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▎         | 37/1022 [01:13<48:49,  2.97s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▎         | 38/1022 [01:17<55:28,  3.38s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▍         | 39/1022 [01:19<47:57,  2.93s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▍         | 40/1022 [01:21<42:20,  2.59s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▍         | 41/1022 [01:27<58:53,  3.60s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▍         | 42/1022 [01:32<1:07:18,  4.12s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▍         | 43/1022 [01:34<56:30,  3.46s/it]  /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▍         | 44/1022 [01:36<47:00,  2.88s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   4%|▍         | 45/1022 [01:38<44:39,  2.74s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▍         | 46/1022 [01:41<44:00,  2.71s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▍         | 47/1022 [01:42<38:18,  2.36s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▍         | 48/1022 [01:46<45:33,  2.81s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▍         | 49/1022 [01:50<51:35,  3.18s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▍         | 50/1022 [01:55<57:55,  3.58s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▌         | 53/1022 [01:56<30:21,  1.88s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▌         | 54/1022 [01:58<30:37,  1.90s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   5%|▌         | 56/1022 [02:02<30:51,  1.92s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▌         | 57/1022 [02:04<30:14,  1.88s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▌         | 59/1022 [02:06<24:24,  1.52s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▌         | 60/1022 [02:10<32:16,  2.01s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▌         | 61/1022 [02:11<30:45,  1.92s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▌         | 62/1022 [02:15<39:04,  2.44s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▌         | 63/1022 [02:17<35:04,  2.19s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▋         | 64/1022 [02:22<48:07,  3.01s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   6%|▋         | 65/1022 [02:24<41:49,  2.62s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 67/1022 [02:25<29:10,  1.83s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 69/1022 [02:27<23:27,  1.48s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 70/1022 [02:30<26:39,  1.68s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 71/1022 [02:31<27:21,  1.73s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 73/1022 [02:33<22:20,  1.41s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 74/1022 [02:38<32:05,  2.03s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 75/1022 [02:39<30:17,  1.92s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   7%|▋         | 76/1022 [02:43<37:58,  2.41s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 77/1022 [02:45<34:39,  2.20s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 78/1022 [02:48<41:36,  2.64s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 79/1022 [02:53<48:42,  3.10s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 80/1022 [02:54<41:53,  2.67s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 81/1022 [02:56<38:24,  2.45s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 82/1022 [03:00<46:07,  2.94s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 83/1022 [03:02<40:35,  2.59s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 84/1022 [03:04<36:31,  2.34s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 85/1022 [03:06<35:34,  2.28s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   8%|▊         | 86/1022 [03:08<32:44,  2.10s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▊         | 87/1022 [03:12<43:52,  2.82s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▊         | 88/1022 [03:16<50:51,  3.27s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▊         | 89/1022 [03:18<43:19,  2.79s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 90/1022 [03:20<41:20,  2.66s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 91/1022 [03:22<37:57,  2.45s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 92/1022 [03:23<27:27,  1.77s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 93/1022 [03:24<26:48,  1.73s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 94/1022 [03:26<25:56,  1.68s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 95/1022 [03:28<29:48,  1.93s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 96/1022 [03:30<28:31,  1.85s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#   9%|▉         | 97/1022 [03:34<38:36,  2.50s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#  10%|▉         | 99/1022 [03:36<26:43,  1.74s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#  10%|▉         | 100/1022 [03:37<26:34,  1.73s/it]/home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:458: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /home/khalo/miniconda3/envs/boeing/lib/python3.9/site-packages/osmnx/simplification.py:506: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
#  10%|▉         | 101/1022 [03:39<33:23,  2.18s/it]
